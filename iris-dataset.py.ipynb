# %%
import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
import pandas as pd

csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Class']
iris = pd.read_csv("C:/IRIS.csv", names=col_names)

print(iris.head())
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0  sepal_length  sepal_width  petal_length  petal_width      species
# 1           5.1          3.5           1.4          0.2  Iris-setosa
# 2           4.9            3           1.4          0.2  Iris-setosa
# 3           4.7          3.2           1.3          0.2  Iris-setosa
# 4           4.6          3.1           1.5          0.2  Iris-setosa

# %%
import pandas as pd


try:
    df = pd.read_csv("C:/IRIS.csv")
  
    df.info()
except NameError as e:
    print(f"NameError: {e}")
except FileNotFoundError:
    print("Error: The file 'IRIS.csv' was not found.  Check the file path.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
import pandas as pd


try:
    df = pd.read_csv("C:/IRIS.csv")

    
    description = df.describe().T
    print(description)

except FileNotFoundError:
    print("Error: The file 'IRIS.csv' was not found. Check the file path.")
except NameError as e:
    print(f"NameError: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
import pandas as pd


try:
    df = pd.read_csv("C:/IRIS.csv") 
except FileNotFoundError:
    print("Error: CSV file not found.")
    exit()
except Exception as e:
    print(f"An error occurred while reading the CSV file: {e}")
    exit()



print("Column names in DataFrame:")
print(df.columns)


if 'Names' in df.columns: 
    print("Contents of 'Names' column:")
    print(df['Names'])
else:
    print("The 'Names' column does not exist in the DataFrame.")
# Out:
# Column names in DataFrame:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# The 'Names' column does not exist in the DataFrame.

# %%
if 'species' in df.columns:
    try:
        print(df['species'].unique())  
    except Exception as e:
        print(f"An error occurred while processing the 'species' column: {e}")
else:
    print("The 'species' column does not exist in the DataFrame.")
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


print("DataFrame Columns:", df.columns)  

if 'sepal_width' in df.columns and 'sepal_length' in df.columns:
    try:
        sns.scatterplot(x='sepal_width', y='sepal_length', data=df, color='purple')
        plt.show()  
    except ValueError as e:
        print(f"ValueError during plotting: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
else:
    print("One or both of the required columns ('sepal_width', 'sepal_length') are missing.")
# Out:
# DataFrame Columns: Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = {'SepalWidthCm': [3.5, 3.0, 3.2, 3.1, 3.6],
        'SepalLengthCm': [5.1, 4.9, 4.7, 4.6, 5.0]}
df = pd.DataFrame(data)

print(df.columns)  

sns.jointplot(x='SepalWidthCm', y='SepalLengthCm', data=df, color='green')
plt.show()
# Out:
# Index(['SepalWidthCm', 'SepalLengthCm'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'SepalWidthCm': [3.5, 3.0, 3.2, 3.1, 3.6],
        'SepalLengthCm': [5.1, 4.9, 4.7, 4.6, 5.0],
        'Species': ['setosa', 'setosa', 'versicolor', 'versicolor', 'virginica']}
df = pd.DataFrame(data)
print(df.columns)  

sns.scatterplot(x='SepalWidthCm', y='SepalLengthCm', data=df, hue='Species')
plt.show()
# Out:
# Index(['SepalWidthCm', 'SepalLengthCm', 'Species'], dtype='object')

# %%
def FunctionName(args):
    f["species"].value_counts()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = {'SepalWidthCm': [3.5, 3.0, 3.2, 3.1, 3.6]}
df = pd.DataFrame(data)

print(df.columns)  

sns.violinplot(y='SepalWidthCm', data=df, color='pink')
plt.show()
# Out:
# Index(['SepalWidthCm'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'Species': ['setosa', 'versicolor', 'virginica'],
        'SepalLengthCm': [5.1, 4.9, 4.7]}
df = pd.DataFrame(data)
print(df.columns)  

sns.violinplot(x='Species', y='SepalLengthCm', data=df)
plt.show()
# Out:
# Index(['Species', 'SepalLengthCm'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'Species': ['setosa', 'versicolor', 'virginica', 'setosa', 'versicolor']}
df = pd.DataFrame(data)
print(df.columns)  

sns.countplot(x='Species', data=df)
plt.show()
# Out:
# Index(['Species'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = {'sepal_width': [3.5, 3.0, 3.2, 3.1, 3.6],
        'sepal_length': [5.1, 4.9, 4.7, 4.6, 5.0],
        'species': ['setosa', 'setosa', 'versicolor', 'versicolor', 'virginica']}
df = pd.DataFrame(data)

print(df.columns)  


sns.lmplot(x='sepal_width', y='sepal_length', data=df, hue='species')
plt.show()
# Out:
# Index(['sepal_width', 'sepal_length', 'species'], dtype='object')

# %%
sns.barplot(x='species', y='sepal_length', data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.catplot(x='species', y='sepal_length', data=df)

# %%
sns.pairplot(df, hue="species", palette="Set2")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = {'petal_length': [1.4, 1.3, 1.5, 1.4, 1.7],
        'sepal_length': [5.1, 4.9, 4.7, 4.6, 5.0]}
df = pd.DataFrame(data)

print(df.columns)  


sns.jointplot(x="petal_length", y="sepal_length", data=df, kind="kde", color="purple")
plt.show()
# Out:
# Index(['petal_length', 'sepal_length'], dtype='object')
